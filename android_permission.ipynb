# %% [markdown]
# # **Android Permission Dataset**
# # Classify android apps into Benign or Malware
#
# ## Aprenentatge Computacional Cas Kaggle
#
# ### **Autor:** Iker Soto Picón
# ### **NIU:** 1565939

# %% [markdown]
# ## **Analitzant les dades**
# L'objectiu d'aquest primer apartat serà conèixer la base de dades que es té entre mans. S'analitzaran els diferents atributs que la composen, s'entendran i s'escogirà quin és l'atribut objectiu a classificar dels que hi ha a la base de dades.

# %%
from sklearn.datasets import make_regression
import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import scipy.stats
import seaborn as sns

# Funcio per a llegir dades en format csv
def load_dataset(path):
    dataset = pd.read_csv(path, header=0, delimiter=',')
    return dataset

# Carreguem dataset
df = load_dataset("/home/gepeto/Desktop/UNI/aprenentatge computacional/practiques/kaggle/git-rep/archive/Android_Permission.csv")

print("Dimensionalitat de la BBDD:", df.shape)
# Out:
# Dimensionalitat de la BBDD: (29999, 184)

# %% [markdown]
# Observem les 5 primeres mostres:

# %%
df.head()
# Out:
#                               App                                   Package  \
# 0         Canada Post Corporation                    com.canadapost.android
# 1                       Word Farm                 com.realcasualgames.words
# 2            Fortunes of War FREE                        fortunesofwar.free
# 3  Better Keyboard: Avatar Purple  com.cc.betterkeyboard.skins.avatarpurple
# 4                      Boxing Day                indiaNIC.android.BoxingDay
#
#            Category                                        Description  \
# 0          Business  Canada Post Mobile App gives you access to som...
# 1    Brain & Puzzle  Speed and strategy combine in this exciting wo...
# 2    Cards & Casino  Fortunes of War is a fast-paced, easy to learn...
# 3  Libraries & Demo  Skin for Better Keyboard featuring a glossy fe...
# 4         Lifestyle  Boxing Day by Christopher Jaymes<p>Based on a ...
#
#    Rating  Number of ratings  Price  \
# 0     3.1                 77   0.00
# ...

# %% [markdown]
# L'atribut objectiu a predir serà **Class**, és a dir, voldrem classificar una app en:
#
#     - 0: Beningn
#
#     - 1: Malware

# %%
data = df.values
# data 
x = data[:, :-1] 

# target
y = data[:, -1]
print("Dimensionalitat de les entrades X", x.shape)
print("Dimensionalitat de l'atribut objectiu Y", y.shape)
# Out:
# Dimensionalitat de les entrades X (29999, 183)
# Dimensionalitat de l'atribut objectiu Y (29999,)

# %%
df.describe()
# Out:
#              Rating  Number of ratings         Price  \
# count  29999.000000       2.999900e+04  29999.000000
# mean       3.537215       6.852608e+03      0.625707
# std        1.424685       4.586899e+04      3.222620
# min        0.000000       0.000000e+00      0.000000
# 25%        3.300000       4.000000e+00      0.000000
# 50%        4.000000       4.600000e+01      0.000000
# 75%        4.400000       7.160000e+02      0.000000
# max        5.000000       1.908590e+06    158.070000
#
#        Dangerous permissions count  Safe permissions count  \
# count                 29795.000000            29999.000000
# mean                      3.111160                1.353978
# std                       3.052602                1.523491
# min                       0.000000                0.000000
# 25%                       1.000000                0.000000
# 50%                       2.000000                1.000000
# 75%                       4.000000                2.000000
# ...

# %% [markdown]
# Comprovem si hi ha atributs no existents:

# %%
"""NAN VALUES"""
# Out:
# 'NAN VALUES'

# %%
print("Per comptar el nombre de valors no existents:")
print(df.isnull().sum())
# Out:
# Per comptar el nombre de valors no existents:
# App                                                                      1
# Package                                                                  0
# Category                                                                 0
# Description                                                              3
# Rating                                                                   0
#                                                                         ..
# Your personal information : set alarm in alarm clock (S)                 0
# Your personal information : write Browser's history and bookmarks (D)    0
# Your personal information : write contact data (D)                       0
# Your personal information : write to user defined dictionary (S)         0
# Class                                                                    0
# Length: 184, dtype: int64

# %% [markdown]
# ## **Tractament de les dades**

# %% [markdown]
# Separem el dataset en dades d'entrenament i de test

# %%
train_size = int(x.shape[0] * 0.7)
X_train = x[:train_size]
X_test = x[train_size:]
y_train = y[:train_size]
y_test = y[train_size:]
